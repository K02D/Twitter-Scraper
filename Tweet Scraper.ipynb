# %%
import twint
import nest_asyncio
nest_asyncio.apply()
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# The following lines of code let you search for tweets that have certain key words in them, filtered by a minimum number of likes.

# %%
# Enter key word to search for in tweets
keyword = "Trump"

# %%
# %%capture
c = twint.Config()
c.Lang = 'en'
c.Limit = 10
c.Search = keyword
c.Min_likes = 10000
c.Pandas = True

twint.run.Search(c)
keyword_df = twint.storage.panda.Tweets_df

# %%
keyword_df = keyword_df[['tweet', 'nlikes', 'nreplies']]
sorted_keyword_df = keyword_df.sort_values(by=['nlikes'], ascending=False)


mean_likes = keyword_df['nlikes'].mean()
mean_replies = keyword_df['nreplies'].mean()

# based on the assumption that more controversial tweets get more replies per like
controversy_metric = mean_replies/mean_likes

sorted_keyword_df['controversy'] = round((sorted_keyword_df['nreplies']/sorted_keyword_df['nlikes'])/controversy_metric, 3)
sorted_keyword_df
# Out:
#                                                                                                                                                                                                                                                                                 tweet  \
# 9                                                                                                                            Obama didn’t hold rallies after Trump got elected. This isn’t normal, it’s an attack on the peaceful transfer of power and it’s dangerous.   #TrumpRally
# 8                                                                                         Whatever you do, do not underestimate Donald Trump like so many did in 2016.  Never forget the evil you are fighting or the power of misinformation used to control low information voters.
# 0                FINE it’s the Trump Vaccine. Two decades of mRNA research had nothing to do with it. The Pfizer vaccine developed prior to WaRp Speed by a Turkish immigrant in Germany meant zero. All Trump. Will THAT get you ignorant crybabies vaccinated? Trump Vaccine it is.
# 5                                                                                                                                                                Dear Republicans who don’t support American first Trump voters ... prepared to be voted out.  Every last one of you.
# 1                                                                                                       Perhaps I'm beginning to understand why many who support Trump don't believe in climate change. It's the middle of a hot summer, and  they seem to be immersed in snowflakes.
# 3                                                                                                                                        Adam Kinzinger and Liz Cheney are not anti-Trump Republicans. They are pro-democracy Republicans. And they’re just about the only ones left.
# 4  Don’t tell me to ignore Trump, Greene, Boebert and all the GOP nutjobs. History is replete with examples of good people ignoring the evil amongst them only to have it destroy everything. We drag their hate into the light and attack it vigorously. Anything else is surrender.
# 6                                                                                                                                                                   Good morning to everyone especially President Trump who was on fire yesterday in front of another enormous crowd.
# 2                                                                        Mitt Romney was a lifelong Republican. John McCain was a lifelong Republican. Lynn Cheney was a lifelong Republican.   Donald Trump wasn’t though. Neither was Ronald Reagan.   I think I’m in good company.
# 7                                                                Donald Trump spent a portion of his speech tonight talking about LeBron James becoming a transgender woman. It’s clear why Trump’s handlers rarely let him out in public anymore. What was left of his mind is gone.
#
#    nlikes  nreplies  controversy
# 9   30213       909        1.340
# 8   27110       515        0.846
# 0   24720       686        1.236
# 5   19812       329        0.740
# 1   17931       312        0.775
# 3   17015       172        0.450
# 4   16810       380        1.007
# 6   16219       217        0.596
# 2   14848       389        1.167
# 7   11470       495        1.922

# %% [markdown]
# The following lines of code let you search for tweets by one twitter user, filtered by a minimum number of likes.

# %%
# Enter twitter @ to search for tweets
user = "BernieSanders"

# %%
# %%capture
c = twint.Config()
c.Limit = 10
c.Username = user
c.Min_likes = 100000
c.Pandas = True

twint.run.Search(c)

user_df = twint.storage.panda.Tweets_df

# %%
user_df = user_df[['tweet', 'nlikes', 'nreplies']]
sorted_user_df = user_df.sort_values(by=['nlikes'], ascending=False)

mean_likes = user_df['nlikes'].mean()
mean_replies = user_df['nreplies'].mean()

controversy_metric = mean_replies/mean_likes

sorted_user_df['controversy'] = round((sorted_user_df['nreplies']/sorted_user_df['nlikes'])/controversy_metric, 3)
sorted_user_df
# Out:
#                                                                                                                                                                                                                                                                                      tweet  \
# 5                                       Some people ask: Why would you impeach and convict a president who has only a few days left in office? The answer: Precedent. It must be made clear that no president, now or in the future, can lead an insurrection against the U.S. government.
# 6               The man directly responsible for the chaos of today is Donald Trump, who has made it clear that he will do anything to remain in power – including insurrection and inciting violence. Trump will go down in history as the worst and most dangerous president in history.
# 9                               Joe Biden will win the popular vote by over 4 million votes. The Democratic nominee for president has now won the popular vote in 7 out of the last 8 elections. One person, one vote. Democracy must rule.  Yes. We should abolish the electoral college.
# 7  All of a sudden Mitch McConnell and Senate Republicans are worried that someone in America might get a $2,000 check "who doesn't need it."  Funny. They had no problem giving a $1.4 billion tax break to Charles Koch and his family with a net worth of $113 billion. What hypocrisy!
# 3                                                                                                                                                                                   “This country has socialism for the rich, rugged individualism for the poor." -Martin Luther King, Jr.
# 4                          Let's be clear. If Trump is too dangerous to send out a tweet or a Facebook post, he's too dangerous to be commander-in-chief. Donald Trump must be removed from office immediately and held accountable for his horrific acts of sedition, violence and chaos.
# 0   Unbelievable. There are some Dems who want to lower the income eligibility for direct payments from $75,000 to $50,000 for individuals, and $150,000 to $100,000 for couples. In other words, working class people who got checks from Trump would not get them from Biden. Brilliant!
# 8        Hmm. What do you call a billionaire who registered a $40 million, 164-foot yacht in the Cayman Islands to avoid $2.4 million in U.S. taxes, while undermining public schools? The worst Education Secretary in the history of America. Bye-bye, Betsy DeVos. You won't be missed.
# 2  Joe Biden will inherit from Trump: The worst economy since the Great Depression, the worst public health crisis in 100 years, massive wealth inequality, the existential threat of climate change, a racist immigration system. These unprecedented crises demand unprecedented action.
# 1  Oh look, another billionaire is mad that he might have to pay more taxes while children in America go hungry and veterans sleep on the street. Cry me a river. Yes. We will make Wall Street billionaires pay their fair share of taxes and create an economy that works for all of us.
#
#    nlikes  nreplies  controversy
# 5  899466     17272        1.007
# 6  567960      7526        0.695
# 9  515540      8101        0.824
# 7  394546      9805        1.304
# 3  341959      1976        0.303
# 4  303442      6209        1.073
# 0  291276     13036        2.348
# 8  241458      4496        0.977
# 2  238738      5411        1.189
# 1  235172      2977        0.664
